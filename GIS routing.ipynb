# %% [markdown]
# # GIS routing

# %% [markdown]
# We won't introduce any new concept/algorithm here.

# %% [markdown]
# Just a new map but we will perform all the algorithms in the same notebook so you could see the difference with respect to time/efficiency

# %% [markdown]
# # Getting the map

# %%
import osmnx as ox
import networkx as nx

# %%
G1 = ox.graph_from_place('toronto premium outlets')
fig, ax = ox.plot_graph(G1)
